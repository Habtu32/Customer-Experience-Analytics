# %%
import pandas as pd

# Load the raw combined reviews
raw_file = "../data/raw/raw_reviews.csv"
df = pd.read_csv(raw_file)

# Show first 5 rows
df.head()
# Out:
#                                reviewId          userName  \
# 0  5112423d-e618-44ba-ba49-62677cb76cd6    Gurawaa Dooguu
# 1  bcb34681-1dd4-4781-b400-4393bb10b1d9  Yohannesb Adugna
# 2  c69f051a-00f8-4144-8423-b7ebcd328d2d  Mohammed Abrahim
# 3  d2995fb9-63c6-4bfc-8d3c-93a0ee9dba8f    Sulxaan Huseen
# 4  f8002d06-b5c5-4ed1-9d51-a9a379304cf8       Sayid Ahmad
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  This application is very important and advanta...      5              0
# 1                          why didn't work this app?      1              0
# ...

# %%
# Check number of rows and columns
print("Shape:", df.shape)

# Check column names
print("Columns:", df.columns)

# Check for missing values
print(df.isnull().sum())
# Out:
# Shape: (2763, 12)
# Columns: Index(['reviewId', 'userName', 'userImage', 'content', 'score',
#        'thumbsUpCount', 'reviewCreatedVersion', 'at', 'replyContent',
#        'repliedAt', 'appVersion', 'app_name'],
#       dtype='object')
# reviewId                   0
# userName                   0
# userImage                  0
# content                    0
# score                      0
# thumbsUpCount              0
# reviewCreatedVersion     619
# at                         0
# replyContent            2761
# repliedAt               2761
# appVersion               619
# app_name                   0
# dtype: int64

# %%
df['app_name'].value_counts()
# Out:
# app_name
# CBE       1000
# BOA       1000
# Dashen     763
# Name: count, dtype: int64

# %%
# Count duplicates
duplicates = df.duplicated(subset=['content'], keep='first').sum()
duplicates
# Out:
# np.int64(552)

# %%
empty_reviews = df['content'].isna().sum() + (df['content'].str.strip() == "").sum()
empty_reviews
# Out:
# np.int64(0)

# %%
# Count missing dates
missing_dates = df['at'].isna().sum()

# See some example date formats
df['at'].head(10)
# Out:
# 0    2025-11-27 20:08:20
# 1    2025-11-27 19:40:35
# 2    2025-11-27 15:00:06
# 3    2025-11-27 13:28:10
# 4    2025-11-27 07:03:41
# 5    2025-11-27 05:59:12
# 6    2025-11-26 09:03:18
# 7    2025-11-25 17:27:20
# 8    2025-11-25 15:10:35
# 9    2025-11-25 14:14:22
# Name: at, dtype: object

# %%
df['content'].sample(10).tolist()
# Out:
# ['Gamebela',
#  'Sorry to say it is very poor apps I have decided to suspend the BoA account',
#  'In your next update can you come with night mode future',
#  'its best',
#  'very fast bank',
#  'The worest mobile banking app',
#  'First ATM in East africa ⭐️⭐️⭐️⭐️⭐️',
#  'This app is not working unless you turn off developer mode on your phone. So it takes your rights to just use it.',
#  'This banking superapp is incredibly well designed. The design and appearance of the app and the overall experience I have when using the app is fantastic. The app is packed with features from banking to e-commerce all in one place.It even has a budget setting option which is super useful for managing my money. Everything runs smoothly and I love how convenient it has made my daily life. Huge Kudos to Dashen Bank. You are truly living up to the motto \'\'Always one step ahead." Keep it up!',
#  'bring back the screenshot feature.']

# %%
df['content'].isna().sum(), (df['content'].str.strip() == "").sum()
# Out:
# (np.int64(0), np.int64(0))

# %%
df.duplicated(subset=['content']).sum()
# Out:
# np.int64(552)

# %%
df['at'].head(10)
# Out:
# 0    2025-11-27 20:08:20
# 1    2025-11-27 19:40:35
# 2    2025-11-27 15:00:06
# 3    2025-11-27 13:28:10
# 4    2025-11-27 07:03:41
# 5    2025-11-27 05:59:12
# 6    2025-11-26 09:03:18
# 7    2025-11-25 17:27:20
# 8    2025-11-25 15:10:35
# 9    2025-11-25 14:14:22
# Name: at, dtype: object

# %%
df['content'].apply(lambda x: any(ord(ch) > 10000 for ch in str(x))).sum()
# Out:
# np.int64(205)
