# %% [markdown]
# ## Load data from the file source

# %%
import pandas as pd

# Load the raw combined reviews
raw_file = "../data/raw/raw_reviews.csv"
df = pd.read_csv(raw_file)

# Show first 5 rows
df.head()
# Out:
#                                               review  rating  \
# 0  This application is very important and advanta...       5
# 1                          why didn't work this app?       1
# 2      The app makes our life easier. Thank you CBE!       5
# 3                                this app very bad 👎       1
# 4       the most advanced app. but how to stay safe?       5
#
#                   date bank             source
# 0  2025-11-27 20:08:20  CBE  Google Play Store
# 1  2025-11-27 19:40:35  CBE  Google Play Store
# 2  2025-11-27 15:00:06  CBE  Google Play Store
# 3  2025-11-27 13:28:10  CBE  Google Play Store
# 4  2025-11-27 07:03:41  CBE  Google Play Store

# %% [markdown]
# ## Check How many reviews per bank?

# %%
reviews_per_bank = df['bank'].value_counts()
print("Number of reviews per bank:")
print(reviews_per_bank)
# Out:
# Number of reviews per bank:
# bank
# CBE       1000
# BOA       1000
# Dashen     763
# Name: count, dtype: int64

# %% [markdown]
# ## check for duplicated for each bank

# %%
duplicate_reviews_per_bank = df.groupby('bank')['review'].apply(lambda x: x.duplicated().sum())
print("Number of duplicate reviews per bank:")
print(duplicate_reviews_per_bank)
# Out:
# Number of duplicate reviews per bank:
# bank
# BOA       145
# CBE       227
# Dashen     99
# Name: review, dtype: int64

# %% [markdown]
# ## check for missing data for each bank

# %%
missing_data_per_bank = df.groupby('bank').apply(lambda x: x.isnull().sum())
print("Missing data for each bank:")
print(missing_data_per_bank)
# Out:
# Missing data for each bank:
#         review  rating  date  bank  source
# bank
# BOA          0       0     0     0       0
# CBE          0       0     0     0       0
# Dashen       0       0     0     0       0
# C:\Users\Hwendifraw\AppData\Local\Temp\ipykernel_23904\4231895053.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   missing_data_per_bank = df.groupby('bank').apply(lambda x: x.isnull().sum())

# %% [markdown]
# ## removing duplicated reviews

# %%
df_cleaned_reviews_no_duplicates = df.drop_duplicates(subset=['review'])
print(f"Number of reviews after removing duplicates: {len(df_cleaned_reviews_no_duplicates)}")
# Out:
# Number of reviews after removing duplicates: 2211

# %%
reviews_per_bank_no_duplicates = df_cleaned_reviews_no_duplicates['bank'].value_counts()
print("\nNumber of reviews per bank after removing duplicates:")
print(reviews_per_bank_no_duplicates)
# Out:
# Number of reviews per bank after removing duplicates:
# bank
# BOA       820
# CBE       773
# Dashen    618
# Name: count, dtype: int64

# %% [markdown]
# ## Normalizing date

# %%
df_cleaned_reviews_no_duplicates['date'] = pd.to_datetime(df_cleaned_reviews_no_duplicates['date'])
df_cleaned_reviews_no_duplicates['date'] = df_cleaned_reviews_no_duplicates['date'].dt.strftime('%Y-%m-%d')
display(df_cleaned_reviews_no_duplicates.head())
# Out:
# C:\Users\Hwendifraw\AppData\Local\Temp\ipykernel_23904\2478607283.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned_reviews_no_duplicates['date'] = pd.to_datetime(df_cleaned_reviews_no_duplicates['date'])
# C:\Users\Hwendifraw\AppData\Local\Temp\ipykernel_23904\2478607283.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned_reviews_no_duplicates['date'] = df_cleaned_reviews_no_duplicates['date'].dt.strftime('%Y-%m-%d')
#                                               review  rating        date bank  \
# 0  This application is very important and advanta...       5  2025-11-27  CBE
# 1                          why didn't work this app?       1  2025-11-27  CBE
# 2      The app makes our life easier. Thank you CBE!       5  2025-11-27  CBE
# 3                                this app very bad 👎       1  2025-11-27  CBE
# 4       the most advanced app. but how to stay safe?       5  2025-11-27  CBE
#
#               source
# 0  Google Play Store
# 1  Google Play Store
# 2  Google Play Store
# 3  Google Play Store
# 4  Google Play Store

# %% [markdown]
# ## saved cleaned file

# %%
output_df = df_cleaned_reviews_no_duplicates[['review', 'rating', 'date', 'bank', 'source']]
output_file_path = '../data/processed/cleaned_reviews_final.csv'
output_df.to_csv(output_file_path, index=False)
print(f"DataFrame saved to {output_file_path}")
# Out:
# DataFrame saved to ../data/processed/cleaned_reviews_final.csv
